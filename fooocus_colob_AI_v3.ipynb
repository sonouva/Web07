# %% [markdown]
# <a href="https://colab.research.google.com/github/sonouva/Web07/blob/master/fooocus_colob_AI_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 60.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 26.81 MiB/s, done.
# Resolving deltas: 100% (3854/3854), done.
# /content/Fooocus

# %% [markdown]
# CheckPoints

# %%
# !wget -O /content/Fooocus/models/checkpoints/realismEngineSDXL_v30VAE.safetensors https://civitai.com/api/download/models/1920523
# Out:
# --2025-07-18 09:25:51--  https://civitai.com/api/download/models/1920523
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/81744/epicrealismxl.NC5J.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22epicrealismXL_vxviiCrystalclear.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250718/us-east-1/s3/aws4_request&X-Amz-Date=20250718T092552Z&X-Amz-SignedHeaders=host&X-Amz-Signature=d5765b6f6f6946a854c14cb8b2cfb7dee19e2a080859ffa28c3edc4d98148b10 [following]
# ...

# %%
# !wget -O /content/Fooocus/models/checkpoints/lazymixRealAmateur_v40.safetensors https://civitai.com/api/download/models/300972
# Out:
# --2025-07-18 09:27:35--  https://civitai.com/api/download/models/300972
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/15946/lazyplusV4Fp16VAE.mSoW.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22lazymixRealAmateur_v40.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250718/us-east-1/s3/aws4_request&X-Amz-Date=20250718T092735Z&X-Amz-SignedHeaders=host&X-Amz-Signature=221f6de8afc5bde4397208c70956625e605ea5d5490c521e370bb7b9ab8a43f8 [following]
# ...

# %%
# !wget -O /content/Fooocus/models/checkpoints/SDXL_1_0_ArienMixXL.safetensors https://civitai.com/api/download/models/448627
# Out:
# --2025-07-18 09:28:25--  https://civitai.com/api/download/models/448627
# Resolving civitai.com (civitai.com)... 172.66.152.186, 104.20.38.219, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|172.66.152.186|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1353487/sdxlArienmixsdxl20asian.W4Ow.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22sdxl10ArienmixxlAsian_v45Pruned.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250718/us-east-1/s3/aws4_request&X-Amz-Date=20250718T092826Z&X-Amz-SignedHeaders=host&X-Amz-Signature=3b6a01ce46fb6d8a76364061182db1f94eff4a927e424b67cd08a6bb20bc1780 [following]
# ...

# %%
# !wget -O /content/Fooocus/models/checkpoints/realisticPonxl_v10B.safetensors https://civitai.com/api/download/models/1992689
# Out:
# --2025-07-18 09:30:06--  https://civitai.com/api/download/models/1992689
# Resolving civitai.com (civitai.com)... 172.66.152.186, 104.20.38.219, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|172.66.152.186|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/10253/realisticponxlV10x0925.bvb2.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22realisticPonxl_v10B.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250718/us-east-1/s3/aws4_request&X-Amz-Date=20250718T093006Z&X-Amz-SignedHeaders=host&X-Amz-Signature=077082371d045d174889be4fa1251ec1a9a4dc4a94e2e1485c002bd4977fea4e [following]
# ...

# %%
 # !wget -O /content/Fooocus/models/checkpoints/realisticBlendXL_v30.safetensors https://civitai.com/api/download/models/2019077
# Out:
# --2025-07-18 09:31:26--  https://civitai.com/api/download/models/2019077
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/4576191/realistic20blend20V3.gOBw.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22realisticBlendXL_v30.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250718/us-east-1/s3/aws4_request&X-Amz-Date=20250718T093126Z&X-Amz-SignedHeaders=host&X-Amz-Signature=35b5988f21b918ba0029ef271fa7886623f63e4ae99b0544d82af57ea4621dbe [following]
# ...

# %% [markdown]
# LoRas

# %%
# !wget -O /content/Fooocus/models/loras/chinesedollidolv1.safetensors https://civitai.com/api/download/models/81566
# Out:
# --2025-07-18 09:33:52--  https://civitai.com/api/download/models/81566
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/731699/model/chinesedollidolv1.PucU.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22chinesedollidolv1.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250718/us-east-1/s3/aws4_request&X-Amz-Date=20250718T093352Z&X-Amz-SignedHeaders=host&X-Amz-Signature=4bf33e9831e2ca78d7bd13d123f64244110b5e0c4ce193068b905fe675701066 [following]
# ...

# %%
 # !wget -O /content/Fooocus/models/loras/Virtual_Asian_Female_Character_26_flux_epoch01.safetensors https://civitai.com/api/download/models/1901347
# Out:
# --2025-07-18 09:33:54--  https://civitai.com/api/download/models/1901347
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 10.7MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 9.78MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 102MB/s]
# ...
